# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/tanya-mac/Desktop/Health Risk Predictor from Lifestyle & Medical History/data/raw/augmented_risks_with_noise.csv")

# %%
df.head()
# Out:
#    Age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   52  Female     White      Highschool        Middle          Employed
# 2   60    Male  Hispanic      Highschool        Middle        Unemployed
# 3   74  Female     Black      Highschool           Low           Retired
# 4   46    Male     White        Graduate        Middle           Retired
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             0
# 1         Former                             1
# 2          Never                             1
# 3          Never                             0
# 4          Never                             1
#
#    physical_activity_minutes_per_week  diet_score  ...  triglycerides  \
# 0                                 215         5.7  ...            145
# 1                                 143         6.7  ...             30
# ...

# %%
df = df.rename(columns={
    "Diabetes_risk_score_custom": "diabetes_risk_score",
    "Hypertension_risk_score_custom": "hypertension_risk_score",
    "HeartDisease_risk_score_custom": "heart_disease_risk_score",
    "Obesity_risk_score_custom": "obesity_risk_score",
    "Cholesterol_risk_score_custom": "cholesterol_risk_score"
})

# %%
df.head()
# Out:
#    Age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   52  Female     White      Highschool        Middle          Employed
# 2   60    Male  Hispanic      Highschool        Middle        Unemployed
# 3   74  Female     Black      Highschool           Low           Retired
# 4   46    Male     White        Graduate        Middle           Retired
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             0
# 1         Former                             1
# 2          Never                             1
# 3          Never                             0
# 4          Never                             1
#
#    physical_activity_minutes_per_week  diet_score  ...  triglycerides  \
# 0                                 215         5.7  ...            145
# 1                                 143         6.7  ...             30
# ...

# %%
df.to_csv("/Users/tanya-mac/Desktop/Health Risk Predictor from Lifestyle & Medical History/data/processed/final_data.csv", index=False)
